# %% [markdown]
# <a href="https://colab.research.google.com/github/vandanakapavarapu/FMML_LAB_1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 04:57:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  81.2MB/s    in 0.9s
#
# 2024-04-03 04:57:37 (81.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6320   1611.03231v1  Direct contextual policy search methods learn ...  stat
# 32713  1501.06237v1  Semi-supervised clustering is an very importan...    cs
# 39814  1705.05016v1  This paper presents a new method for 3D shape ...    cs
# 22667  1703.10827v1  Objective: In this work, we perform margin ass...  stat
# 21599   1108.4324v3  In sparse Bayesian learning (SBL), Gaussian sc...  stat
# ...             ...                                                ...   ...
# 8160    1403.1024v4  Learning to localize objects with minimal supe...    cs
# 21994   1310.3003v3  A novel linear classification method that poss...  stat
# 4370   1608.04664v2  We address the task of simultaneous feature fu...  stat
# 6540   1703.02102v2  Off-policy stochastic actor-critic methods rel...  stat
# 12386  1801.00315v1  Inspired by coarse-graining approaches used in...  stat
#
#                                                    title  year  \
# 6320   Policy Search with High-Dimensional Context Va...  2016
# 32713  Deep Transductive Semi-supervised Maximum Marg...  2015
# 39814  A Correspondence Relaxation Approach for 3D Sh...  2017
# 22667  Intraoperative margin assessment of human brea...  2017
# 21599  Sparse Estimation using Bayesian Hierarchical ...  2011
# ...                                                  ...   ...
# 8160   On learning to localize objects with minimal s...  2014
# 21994           Distance-weighted Support Vector Machine  2013
# 4370   Variational Gaussian Process Auto-Encoder for ...  2016
# 6540   Revisiting stochastic off-policy action-value ...  2017
# 12386  Learning Relevant Features of Data with Multi-...  2017
#
#                                                 keywords
# 6320   [contextual, parameters, simultaneously, gener...
# 32713  [supervised, clustering, important, challenge,...
# 39814  [reconstruction, reconstruction, photograph, i...
# 22667  [objective, assessment, coherence, tomography,...
# 21599  [functions, regression, motivated, functions, ...
# ...                                                  ...
# 8160   [supervision, important, annotated, extremely,...
# 21994  [classification, possesses, discrimination, cl...
# 4370   [simultaneous, particular, introduce, responsi...
# 6540   [stochastic, approximating, stochastic, approx...
# 12386  [approaches, algorithms, resulting, algorithms...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6320     [contextual, parameters, simultaneously, gener...
# 32713    [supervised, clustering, important, challenge,...
# 39814    [reconstruction, reconstruction, photograph, i...
# 22667    [objective, assessment, coherence, tomography,...
# 21599    [functions, regression, motivated, functions, ...
#                                ...
# 21851    [different, approaches, information, dependenc...
# 3711     [submodular, functions, functions, naturally, ...
# 9377     [optimization, constraint, practical, applicat...
# 10381    [distributed, dictionary, collectively, dictio...
# 9700     [classification, constitutes, important, preli...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8850 words.
# Out of those 4648 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="60e9776d-17cf-4b59-96b6-f55bd51adb3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e9776d-17cf-4b59-96b6-f55bd51adb3a")) {                    Plotly.newPlot(                        "60e9776d-17cf-4b59-96b6-f55bd51adb3a",                        [{"x":["regularization","dimensionality","furthermore","different","supervised","principal","reduction","quadratic","application","framework","variables","simultaneously","integrated","component","contextual","stochastic","dimensional","parameters","insufficient","prominent","unsupervised","outperforms","generalize","experimental","objective","automatically","structure","attention","boltzmann","transductive","techniques","clustering","constraints","instances","backpropagation","challenge","restricted","unlabeled","representations","fortunately","specifically","important","significantly","according","estimation","demonstrates","difference","relaxation","correspondence","promising","reconstruction","establishment","experiment","introduced","photograph","competing","coherence","demonstrated","approximately","configurations","specificity","assessment","simulates","sensitivity","conservative","tomography","significance","available","diminishing","conclusion","complexity","intraoperative","correlation","comparison","introduces","automated","overfitting","coefficient","evaluated","literature","collected","computationally","convergence","modification","properties","maximization","depending","robustness","expectation","hierarchical","sparseness","formulated","estimated","estimators","algorithms","functions","estimator","regression","superiority","numerical","motivated","algorithm","solutions","polynomial","inference","increasingly","dirichlet","nonparametric","parametric","processes","especially","flexibility","allocation","submodularity","nonparametrics","prohibitively","including","parameter","learnable","extensive","convolutional","subjected","upsampling","remainder","processing","preserving","transformation","architectural","downsampling","colorization","denoising","architecture","recursive","efficient","generalized","recursively","regressor","deconvolutional","branching","comprising","representation","comparable","machinery","modifications","extraction","collection","difficulty","particularly","relatively","mathematical","knowledge","discussion","appealing","selection","underlying","observations","applications","successful","spectrometry","theoretical","surprisingly","structures","assumptions","practical","arbitrary","guarantee","expensive","previously","execution","accuracies","bandwidth","surpasses","efficiency","footprint","computational","appropriate","precision","activations","activation","analyzing","investigations","direction","performance","implementation","analytics","semantics","traditional","prediction","conclusions","information","guideline","researchers","investigate","significant","discussions","benchmarks","competitive","categories","conducted","classifying"],"y":[80,61,176,742,182,43,104,32,253,551,118,111,56,115,53,130,162,228,10,14,120,261,48,388,170,172,343,162,15,3,391,131,158,100,20,146,52,39,219,3,176,343,262,99,194,57,53,20,25,119,91,3,87,122,2,23,20,78,29,15,9,48,8,31,4,14,16,317,2,19,234,3,78,141,82,98,21,28,154,144,76,69,127,27,198,35,35,97,40,80,3,45,67,16,568,233,28,108,41,68,69,798,147,62,205,45,14,25,29,119,126,30,27,3,1,6,242,136,8,167,353,3,5,1,303,55,58,8,5,8,29,256,26,390,60,8,4,3,10,13,346,93,5,17,147,83,43,81,59,71,356,34,12,128,119,67,426,65,0,152,34,147,64,145,90,40,65,106,31,21,9,2,196,9,271,83,91,28,35,55,9,57,879,125,20,99,186,223,17,713,4,82,142,251,14,96,110,64,76,37],"type":"bar"},{"x":["regularization","dimensionality","furthermore"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4648,), (4648, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>MODNet</span> <span style=''>Moving</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.5022421524663678);'>Detection</span> <span style=''>Network</span> <span style=''>with</span> <span style=''>Motion</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.9090909090909091);'>Appearance</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7878787878787878);'>Autonomous</span> <span style=''>Driving</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>system</span> <span style=''>that</span> <span style=''>combines</span> <span style='background-color:rgba(0, 255, 0, 0.9090909090909091);'>appearance</span> <span style=''>and</span> <span style=''>motion</span> <span style=''>cues</span> <span style=''>for</span> <span style=''>a</span> <span style=''>better</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.7534246575342466);'>reasoning</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6100628930817611);'>environment</span> <span style=''>A</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.5515151515151515);'>architecture</span> <span style=''>for</span> <span style=''>joint</span> <span style=''>vehicle</span> <span style='background-color:rgba(0, 255, 0, 0.5022421524663678);'>detection</span> <span style=''>and</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.6422018348623852);'>segmentation</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.5515151515151515);'>architecture</span> <span style=''>a</span> <span style=''>two</span> <span style=''>stream</span> <span style=''>encoder</span> <span style=''>is</span> <span style=''>shared</span> <span style=''>among</span> <span style=''>both</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>our</span> <span style=''>method</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.7878787878787878);'>autonomous</span> <span style=''>driving</span> <span style=''>setting</span> <span style=''>KITTI</span> <span style='background-color:rgba(0, 255, 0, 0.87012987012987);'>annotated</span> <span style='background-color:rgba(0, 255, 0, 0.42657342657342656);'>sequences</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.5022421524663678);'>detection</span> <span style=''>and</span> <span style=''>odometry</span> <span style=''>ground</span> <span style=''>truth</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3543307086614173);'>automatically</span> <span style=''>generate</span> <span style=''>staticdynamic</span> <span style='background-color:rgba(0, 255, 0, 0.8688524590163935);'>annotations</span> <span style=''>on</span> <span style=''>the</span> <span style=''>vehicles</span> <span style=''>This</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>called</span> <span style=''>KITTI</span> <span style=''>Moving</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.5022421524663678);'>Detection</span> <span style=''>dataset</span> <span style=''>(KITTI</span> <span style=''>MOD)</span> <span style=''>The</span> <span style=''>dataset</span> <span style=''>will</span> <span style=''>be</span> <span style=''>made</span> <span style=''>publicly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Auto</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associative</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>pursuit</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>auto</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associative</span> <span style=''>models</span> <span style=''>are</span> <span style=''>proposed</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidates</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>by</span> <span style=''>a</span> <span style=''>manifold</span> <span style=''>Here</span> <span style=''>the</span> <span style=''>word</span> <span style=''>manifold</span> <span style=''>refers</span> <span style=''>to</span> <span style=''>the</span> <span style=''>topology</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>manifold</span> <span style=''>is</span> <span style=''>built</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>pursuit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>At</span> <span style=''>each</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>is</span> <span style=''>incremented</span> <span style=''>Some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>are</span> <span style=''>provided</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>can</span> <span style=''>show</span> <span style=''>that</span> <span style=''>at</span> <span style=''>each</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>the</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>norm</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>Moreover</span> <span style=''>it</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sub</span> <span style=''>sampled</span> <span style=''>Cubic</span> <span style='background-color:rgba(255, 0, 0, 0.30131004366812225);'>Regularization</span> <span style=''>for</span> <span style=''>Non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>arise</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.37872340425531925);'>attention</span> <span style=''>on</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>trust</span> <span style=''>region</span> <span style=''>methods</span> <span style=''>known</span> <span style=''>as</span> <span style=''>cubic</span> <span style='background-color:rgba(255, 0, 0, 0.30131004366812225);'>regularization</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attractive</span> <span style=''>because</span> <span style=''>it</span> <span style=''>escapes</span> <span style=''>strict</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>and</span> <span style=''>it</span> <span style=''>provides</span> <span style=''>stronger</span> <span style='background-color:rgba(255, 0, 0, 0.3021978021978022);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>than</span> <span style=''>first</span> <span style=''>and</span> <span style=''>second</span> <span style=''>order</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>trust</span> <span style=''>region</span> <span style=''>methods</span> <span style=''>However</span> <span style=''>it</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>makes</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impractical</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>learning</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>sub</span> <span style=''>sampling</span> <span style=''>to</span> <span style=''>lower</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>By</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentration</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>inequalities</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>that</span> <span style=''>gives</span> <span style='bac ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unwrapping</span> <span style=''>using</span> <span style=''>density</span> <span style=''>ridges</span> <br/><br/><span style=''>Research</span> <span style=''>on</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>within</span> <span style=''>a</span> <span style=''>density</span> <span style=''>ridge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>de</span> <span style=''>noising</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>building</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style=''>and</span> <span style=''>well</span> <span style=''>defined</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>curves</span> <span style=''>and</span> <span style=''>surfaces</span> <span style=''>However</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unwrapping</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unfolding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>has</span> <span style=''>received</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>little</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>within</span> <span style=''>the</span> <span style=''>density</span> <span style=''>ridge</span> <span style=''>approach</span> <span style=''>despite</span> <span style=''>being</span> <span style=''>an</span> <span style=''>integral</span> <span style=''>part</span> <span style=''>of</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>general</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>two</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unwrapping</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>curves</span> <span style=''>and</span> <span style=''>surfaces</span> <span style=''>for</span> <span style=''>one</span> <span style=''>and</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respectively</span> <span style=''>The</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unwrapping</span> <span style=''>are</span> <span style=''>founded</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realization</span> <span style=''>that</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style=''>curv ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06399713979263497)
# 	experimental (0.1387200572041473)
# 	processing (0.10833035395066143)
# 	architecture (0.09152663568108688)
# 	knowledge (0.12727922774401143)
# 	information (0.2549159814086521)
# 	detection (0.11977118341079729)
# 	convolutional (0.1262066499821237)
# 	different (0.26528423310690025)
# 	recognition (0.13585984983911334)
#
# Some Statistics words are:
# 	stochastic (0.12631053419870195)
# 	variables (0.13729405891163254)
# 	statistical (0.15327009485771342)
# 	theoretical (0.16075886170743883)
# 	estimation (0.1782326510234648)
# 	algorithm (0.3944083874188717)
# 	distribution (0.19420868696954569)
# 	inference (0.200199700449326)
# 	dimensional (0.18871692461308037)
# 	regression (0.1767348976535197)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="413bdcd2-5c0e-4251-9b00-eaa29bfd10f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("413bdcd2-5c0e-4251-9b00-eaa29bfd10f3")) {                    Plotly.newPlot(                        "413bdcd2-5c0e-4251-9b00-eaa29bfd10f3",                        [{"x":["regularization","dimensionality","furthermore","different","supervised","principal","reduction","quadratic","application","framework","variables","simultaneously","integrated","component","contextual","stochastic","dimensional","parameters","insufficient","prominent","unsupervised","outperforms","generalize","experimental","objective","automatically","structure","attention","boltzmann","transductive","techniques","clustering","constraints","instances","backpropagation","challenge","restricted","unlabeled","representations","fortunately","specifically","important","significantly","according","estimation","demonstrates","difference","relaxation","correspondence","promising","reconstruction","establishment","experiment","introduced","photograph","competing","coherence","demonstrated","approximately","configurations","specificity","assessment","simulates","sensitivity","conservative","tomography","significance","available","diminishing","conclusion","complexity","intraoperative","correlation","comparison","introduces","automated","overfitting","coefficient","evaluated","literature","collected","computationally","convergence","modification","properties","maximization","depending","robustness","expectation","hierarchical","sparseness","formulated","estimated","estimators","algorithms","functions","estimator","regression","superiority","numerical","motivated","algorithm","solutions","polynomial","inference","increasingly","dirichlet","nonparametric","parametric","processes","especially","flexibility","allocation","submodularity","nonparametrics","prohibitively","including","parameter","learnable","extensive","convolutional","subjected","upsampling","remainder","processing","preserving","transformation","architectural","downsampling","colorization","denoising","architecture","recursive","efficient","generalized","recursively","regressor","deconvolutional","branching","comprising","representation","comparable","machinery","modifications","extraction","collection","difficulty","particularly","relatively","mathematical","knowledge","discussion","appealing","selection","underlying","observations","applications","successful","spectrometry","theoretical","surprisingly","structures","assumptions","practical","arbitrary","guarantee","expensive","previously","execution","accuracies","bandwidth","surpasses","efficiency","footprint","computational","appropriate","precision","activations","activation","analyzing","investigations","direction","performance","implementation","analytics","semantics","traditional","prediction","conclusions","information","guideline","researchers","investigate","significant","discussions","benchmarks","competitive","categories","conducted","classifying","inadequate","classification","architectures","evaluating","evaluations","decomposition","beneficial","dimensions","community","popularity","considered","therefore","uniqueness","introduction","decompositions","references","relational","libraries","multidimensional","introduce","factorization","disciplines","optimized","preference","sensitive","adjusting","importance","empirically","prohibits","usefulness","demonstrate","sublinear","approximate","dissimilarity","corresponding","retrieval","imagevideo","dissimilarities","theoretically","comparisons","attracted","accounting","synthetic","utilization","transforming","separable","experiments","neighbors","deformable","spatially","remarkable","improvements","deform ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	spectrometry
# 	prohibits
# 	liblinear
# 	hermitian
# 	mislabeled
# 	unverifiable
# 	missforest
# 	byproduct
# 	overarching
# 	emphdirectly
# 	centering
# 	geodesics
# 	statistician
# 	encapsulate
# 	eigenspaces
# 	tibshirani
# 	smoothers
# 	stratifying
# 	confounder
# 	detectability
# Some words which never appear in Statistics papers:
# 	photograph
# 	subjected
# 	upsampling
# 	downsampling
# 	colorization
# 	surpasses
# 	occlusions
# 	modularly
# 	lifschitz
# 	strengthens
# 	subjectively
# 	impressions
# 	recommends
# 	grounding
# 	plentiful
# 	visibility
# 	concurrently
# 	requesting
# 	operative
# 	equivalents

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065791894046232e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7616666666666667
